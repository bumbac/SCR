# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("../wine/vit_t4.tsv", sep='\t')
df = df.rename(columns={"vinevar,age,unit,geo\\time":"v"})

# %%
df.v.str.contains('*SK*', regex=True, na=False)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_40689/1845044287.py in <module>
# ----> 1 df.v.str.contains('*SK*', regex=True, na=False)
#
# ~/anaconda3/envs/PDD/lib/python3.9/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# ~/anaconda3/envs/PDD/lib/python3.9/site-packages/pandas/core/strings/accessor.py in contains(self, pat, case, flags, na, regex)
#    1151         dtype: bool
#    1152         """
# -> 1153         if regex and re.compile(pat).groups:
#    1154             warnings.warn(
#    1155                 "This pattern has match groups. To actually get the "
#
# ~/anaconda3/envs/PDD/lib/python3.9/re.py in compile(pattern, flags)
# ...

# %%
dfsk = df[df.v.str.contains('*SK*', regex=True, na=False)]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_40689/4094298026.py in <module>
# ----> 1 dfsk = df[df.v.str.contains('*SK*', regex=True, na=False)]
#
# ~/anaconda3/envs/PDD/lib/python3.9/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# ~/anaconda3/envs/PDD/lib/python3.9/site-packages/pandas/core/strings/accessor.py in contains(self, pat, case, flags, na, regex)
#    1151         dtype: bool
#    1152         """
# -> 1153         if regex and re.compile(pat).groups:
#    1154             warnings.warn(
#    1155                 "This pattern has match groups. To actually get the "
#
# ...
